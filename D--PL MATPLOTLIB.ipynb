# %% [markdown]
# ### MATPLOTLIB

# %% [markdown]
# Data Visualization : It is usefull to gain insights and understand what happened in the past in a given context.Itis also helfull for feature engeneering.
#
# Matplotlib library provides simple ways to create boxplots, scatterplots, line graphs, and barcharts distribution plots with custom styling and annotation.Matplotlib is a Python 2D plotting library, It’s useful for simplifying your data visualization tasks.
#
# Detailed documentation for matplotlib can be found at https://matplotlib.org/.
#
# Seaborn is also a Python data visualization library based on matplotlib. It provides a high-level interface for drawing innovative and informative statistical charts (source: https://seaborn.pydata.org/).
#
# To create graphs and plots, we need to import matplotlib.pyplot and seaborn modules. To display the plots on the Jupyter Notebook, we need to provide a directive %matplotlib inline. Only if the directive is provided, the plots will be displayed on the notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a=np.arange(0,5,0.5)
a
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5])

# %%
x=[0.,0.5,1.,1.5,2.,2.5,3.,3.5,4,4.5,5.]
y=[0.,0.25,1.,2.25,4.,6.25,9.,12.25,16.,20.25,25.]

# %%
x
# Out:
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4, 4.5, 5.0]

# %%
y
# Out:
# [0.0, 0.25, 1.0, 2.25, 4.0, 6.25, 9.0, 12.25, 16.0, 20.25, 25.0]

# %%
plt.plot(x,y);

# %%
plt.plot(x,y,'1');

# %%
plt.plot(x,y,':');

# %%
plt.plot(x,y,'m')

# %%
plt.plot(x,y,'X')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("Basic plot");

# %%
# subplot function
# syntax is plt.subplot(nrows,ncol,plotnumber)

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'g')

plt.subplot(1,2,2)
plt.plot(y,x,'r')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'g');

plt.subplot(2,2,2)
plt.plot(y,x,'r');

plt.subplot(2,2,3)
plt.plot(x,y,'b');

plt.subplot(2,2,4)
plt.plot(y,x,'y');

# %%
plt.subplot(1,1,1)
plt.plot(x,y)
plt.plot(y,x)

# %%
#subplot function
fig=plt.figure()

# %%
fig=plt.figure()
fig,a=plt.subplots(2,2)
a[0,0].plot(x,y,'y')
a[0,1].plot(y,x,'b')
a[1,0].plot(x,y,'r')
a[1,1].plot(y,x,'g')

# %%
fig=plt.figure()
fig,a=plt.subplots(1,2)
a[0].plot(x,y)
a[1].plot(y,x)

# %%
fig=plt.figure()
fig,a=plt.subplots(2,2)

a[0,0].plot(x,y)
a[0,0].set_title('plot 1')

a[0,1].plot(y,x)
a[0,1].set_title('plot 2')

a[1,0].plot(x,y)
a[1,0].set_title('plot 3')

a[1,1].plot(y,x)
a[1,1].set_title('plot 4')

plt.tight_layout();  ## to avoid overlapping(spaces)
plt.tight_layout(pad=3.0);  ## more spaces brtween the plots

# %%
fig,a=plt.subplots(figsize=(12,3))
a.plot(x,y,'b')
a.set_xlabel('x')
a.set_ylabel('y')
a.set_title('TITLE');

# %%
fig.savefig(r'C:\Users\Admin\Pictures\Saved Pictures.png')

# %%
# dots per inch\pixel per inch----dpi
fig.savefig(r"C:\Users\Admin\Pictures\Saved Pictures.png",dpi=200)

# %%
import matplotlib.image as mpimg
img=mpimg.imread(r"C:\Users\Admin\Pictures\Saved Pictures\pandas.jpg")

# %%
plt.imshow(img)

# %%
import matplotlib.image as mpimg
im=mpimg.imread(r"C:\Users\Admin\Pictures\Saved Pictures\koala.jpg")
plt.imshow(im)

# %%
plt.axis('off')  ## image will be displayed without axis points
plt.imshow(img)

# %%
fig=plt.figure()

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# matplotlib style line color and style
fig,ax=plt.subplots()
ax.plot(x,x**2,'b') ## blue line with dots
ax.plot(x,x**3,color='#b22222')  ## http://html color codes.com

# %% [raw]
# fig,ax =plt.subplots()
# ax.plot(x,x**2,'b',marker='s',markersize=9,lw=5,markerfacecolor='red',markeredgecolor='yellow',markeredgewidth=3)
# ax.plot(x,x**3,'b',ls='_ _',lw=y);

# %%
fig,axes=plt.subplots(1,2,figsize=(12,4))
axes[0].plot(x,x**2,x,x**3)
axes[0].set_title("Default axes ranges")

axes[1].plot(x,x**2,x,x**3)
axes[1].set_ylim([0,60])
axes[1].set_xlim([2,5])
axes[1].set_title("custom axes ranges")
plt.suptitle("my plotting");

# %%
# scatter diagram
fig=plt.figure()
x=np.linspace(15,45,13)
y=x%2

# %%
x
# Out:
# array([15. , 17.5, 20. , 22.5, 25. , 27.5, 30. , 32.5, 35. , 37.5, 40. ,
#        42.5, 45. ])

# %%
y
# Out:
# array([1. , 1.5, 0. , 0.5, 1. , 1.5, 0. , 0.5, 1. , 1.5, 0. , 0.5, 1. ])

# %%
plt.scatter(x,y,marker='8')

# %%
## Bar Charts

# %%
x=['python','c','java']
y=[20,50,80]
a=plt.bar(x,y,width=0.6)
a[0].set_color('r')
a[1].set_color('b')
a[2].set_color('g')
plt.grid(True,lw=4,color='black')
