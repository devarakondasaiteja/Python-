# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn is another data visualization library based on Matplotlib that allows for visulize the statistical graphs,  like confidence intervals, distributions, and other graphs like Line Plot,Scatter Plot, Box plot, Point plot, Count plot, Violin plot, Swarm plot, Bar plot, KDE Plot,histogram,Whiskers Plot, Pairwise Plots.

# %% [markdown]
# Seaborn helps to visualize the statistical relationships, To understand how variables in a dataset are related to one another and how that relationship is dependent on other variables, we perform statistical analysis helps to visualize the trends and identify various patterns in the dataset.

# %% [markdown]
#  In order to draw a histogram in Seaborn, we have a function called distplot and inside that, we have to pass the variable which we want to include. Histogram with default kernel density estimate:

# %% [markdown]
# ## seaborn conceptes :
# ### Distribution Plot-  Dist plot, joint plot, pair plot
# ### Categorical Plot -  Bar plot, count plot, box plot, cat plot
# ### Matrix Plot
# ### Grids-  Pair grids, Facet grid, joint grid, regression plot
# ### Style and color

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Distribution plot

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
print( sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
#load the datasets

# %%
tips= sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# #### Hist plot

# %% [markdown]
# To construct a histogram, follow these steps −
#
# * Bin the range of values.
# * Divide the entire range of values into a series of intervals.
# * Count how many values fall into each interval.
#   The bins are usually specified as consecutive, non-overlapping intervals of a variable.

# %% [markdown]
# * A histogram is a plot that shows the frequency distribution of a set of continuous variable. Histogram
# gives an insight into the underlying distribution (e.g., normal distribution) of the variable, outliers, skewness, etc. To draw a histogram, invoke hist() method of matplotlib library

# %% [markdown]
# * In order to draw a histogram in Seaborn, we have a function called distplot and inside that, we have to pass the variable which we want to include. Histogram with default kernel density estimate:
#
#
# * the histogram is by default include kernel density estimate (kde). Kernel density estimate is the curved line along with the bins or the edges of the frequency of the Ages. If you want to remove the Kernel density estimate (kde) then use kde = False.
#
#
# * Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable. It is used for non-parametric analysis.Setting the hist flag to False in distplot will yield the kernel density estimation plot.distplot() is used to visualize the parametric distribution of a dataset.
#
# * f you want to organize all the different intervals or bins, you can use the bins parameter on the distplot function. Let’s use bins = 5 on the distplot function. It will organize your bins into five bins or intervals.
#
#
# * Histograms represent the data distribution by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.

# %%
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(tips['total_bill'],bins=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
#sns.histplot(tips['total_bill'],bins=3)
#sns.histplot(tips['total_bill'],bins='auto')

# %%
sns.distplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips['total_bill'],color='r')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
# Dist plot
sns.distplot(tips['total_bill'],kde=False)  # kde - kernel density estimator
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde_kws= {'color':'green', 'lw': 3, 'ls': '--'})
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],hist_kws={'color':'yellow', 'edgecolor': 'red'})
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde_kws={'color':'green','lw':4 ,'ls':'--'}, hist_kws={'color':'red', 'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
print(sns.axes_style)
# Out:
# <function axes_style at 0x0000015EE2109550>

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': (1, 1, 1, 0),
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'projecting',
#  'patch.edgecolor': 'black',
#  'patch.force_edgecolor': False,
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %% [markdown]
# # Joint plot

# %%
sns.jointplot(x='total_bill' ,y='tip',data= tips)

# %%
sns.jointplot(x='total_bill' ,y= 'tip', data=tips ,kind='reg')

# %% [markdown]
# # Pair plot

# %%
# pair plot is the pairwise relationship between all the numerical columns

# %%
sns.pairplot(tips)

# %%
c=['red','green']
sns.pairplot(data=tips ,vars=['total_bill','tip'], palette=c, hue='sex')

# %% [markdown]
# # Categorical plot

# %% [markdown]
# ### BAR PLOT

# %% [markdown]
# Bar chart is a frequency chart for qualitative variable (or categorical variable). Bar chart can be used to assess the most-occurring and least-occurring categories within a dataset.
#
# To draw a bar chart, call barplot() of seaborn library.
#
# sns.barplot(x='sex' , y='total_bill', data=tips , ci=0)
#
# We can also create bar charts, which are grouped by a third variable. The parameter hue takes the third variable as parameter. In this case, we pass sex as hue parameter.
#
# sns.barplot(x='sex', y='total_bill', data=tips ,ci=0, hue='sex', palette='bright')
#
# plt.legend(bbox_to_anchor=(1.3,1.0))

# %%
sns.barplot(x='sex' , y='total_bill' ,data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex' , y='total_bill', data=tips , ci=0)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips ,ci=0, hue='sex', palette='bright')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt
sns.barplot(x='sex', y='total_bill', data=tips ,ci=0, hue='sex', palette='bright')

plt.legend(bbox_to_anchor=(1.3,1.0))

# %% [markdown]
# # count plot

# %%
sns.countplot(x='time',  data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='time',y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
tips[(tips['time']=='Lunch')].min()
# Out:
# total_bill    7.51
# tip           1.25
# size          1.00
# dtype: float64

# %%
sns.boxplot(x='time', y='total_bill', data=tips, hue='time')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.groupby('sex').size()
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %% [markdown]
# # Catplot...categorical plot

# %%
sns.catplot(x='time',data=tips, kind='count')

# %% [markdown]
# # Matrix plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(), annot=True, fmt='.4f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # loding the iris dataset

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # grids

# %%
# pair Grids

# %%
g=sns.PairGrid(iris)

# %%
g=sns.PairGrid(iris)
g.map(sns.scatterplot)

# %%
g=sns.PairGrid(iris,hue='species')
g.map_upper(sns.scatterplot)
g.map_lower(sns.scatterplot)
g.map_diag(plt.hist,histtype='step')

# %%
x_vars=['sepal_length']
y_vars=['sepal_width']
g=sns.PairGrid(iris,hue='species' ,x_vars=x_vars, y_vars=y_vars, palette='bright')
g.map(sns.scatterplot)

# %% [markdown]
# # FacetGrid

# %%
g=sns.FacetGrid(tips, col='time')  # col = time,sex,smoker
g.map(plt.hist, 'total_bill')

# %%
g=sns.FacetGrid(tips, row='sex')
g.map(plt.hist, 'total_bill')

# %%
g=sns.FacetGrid(tips, col='sex')
g.map(plt.hist, 'total_bill')

# %%
g=sns.FacetGrid(tips,col='time', row='smoker', hue='sex')
g.map(plt.scatter,'total_bill', 'tip').add_legend()
g.set_axis_labels('bill xaxis', 'tip yaxis')  # for changing the label x and y

# %% [markdown]
# # Joint Grid

# %%
g=sns.JointGrid(x="total_bill", y="tip", data=tips)
g=g.plot(plt.scatter, sns.distplot)

# %%
g=sns.JointGrid(x="total_bill", y="tip", data=tips)
g=g.plot(plt.scatter, sns.distplot)
g=g.plot_marginals(sns.distplot,kde=False, color="r")

# %%
g=sns.JointGrid(x="total_bill", y="tip", data=tips)
g=g.plot(plt.scatter, sns.distplot)
g.ax_marg_x.hist(tips["total_bill"], color="r", alpha=1)
g.ax_marg_y.hist(tips["tip"], color="g", alpha=1, orientation="horizontal")
g.plot_joint(sns.scatterplot, color='black')

# %% [markdown]
# # Regression plot

# %%
sns.lmplot(x='total_bill',y='tip', data=tips)  # linear model inbuil

# %%
sns.lmplot(x='total_bill',y='tip', data=tips, line_kws={'ls': '--', 'color': 'red'})

# %%
sns.lmplot(x='total_bill',y='tip', data=tips, line_kws={'ls': '--', 'color': 'red'}, scatter_kws={'color':'green'})

# %%
sns.lmplot(x='total_bill',y='tip', data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip', data=tips, col='sex')

# %%
sns.lmplot(x='total_bill',y='tip', data=tips,hue='time',row='time', palette=['red','green'])

# %% [markdown]
# # Style and Color

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex',palette='BuGn', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='time',palette='autumn', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.set_style('white')
sns.countplot(x='day',palette='prism', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.set_style('dark')
sns.countplot(x='sex',palette='prism', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # Spine Removal

# %%
sns.countplot(x='time', palette='jet_r', data=tips)
sns.despine()

# %%
sns.countplot(x='time', palette='spring_r', data=tips)
sns.despine(left=True,bottom=True)

# %% [markdown]
# # Scale and Context

# %%
sns.set_context('paper',font_scale=2)
sns.countplot(x='time',palette='spring_r', data=tips);

# %%
sns.set_context('notebook',font_scale=2)
sns.countplot(x='time',palette='magma', data=tips);

# %%
sns.set_context('talk',font_scale=2)
sns.countplot(x='time',palette='hot', data=tips);

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.yticks([0,50,60,80,100])
sns.set_context('poster',font_scale=2)
sns.countplot(x='time',palette='hot_r', data=tips);
